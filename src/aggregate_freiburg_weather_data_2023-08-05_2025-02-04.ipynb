# %%
import pandas as pd

# %%
df_air_temperature = pd.read_csv("../data/freiburg raw data/air temperature freiburg/freiburg_air_temperature_20230805_20250204_01443.txt",
                                 delimiter=";", usecols=["MESS_DATUM", "RF_TER", "TT_TER"])
df_air_temperature = df_air_temperature.rename(columns={
    "MESS_DATUM": "Measurement_Date",
    "RF_TER": "Relative_Humidity",
    "TT_TER": "Air_Temperature"
})

# Convert 'Measurement_Date' to datetime
df_air_temperature['Measurement_Date'] = pd.to_datetime(df_air_temperature['Measurement_Date'], format='%Y%m%d%H')

# Set the datetime column as the index
df_air_temperature.set_index('Measurement_Date', inplace=True)

# Resample to daily, aggregating with mean for temperature and humidity
df_air_temperature = df_air_temperature.resample('D').agg({
    'Air_Temperature': 'mean',   # Average temperature
    'Relative_Humidity': 'mean'  # Average humidity
})

# %%
df_cloudiness = pd.read_csv("../data/freiburg raw data/freiburg cloudiness data/produkt_n_termin_20230805_20250204_01443.txt", delimiter=";", usecols=["MESS_DATUM","N_TER"])
df_cloudiness = df_cloudiness.rename(columns={
    "MESS_DATUM": "Measurement_Date",
    "N_TER": "Cloud_Cover"
})

df_cloudiness['Measurement_Date'] = pd.to_datetime(df_cloudiness['Measurement_Date'], format='%Y%m%d%H')

df_cloudiness.set_index('Measurement_Date', inplace=True)

df_cloudiness = df_cloudiness.resample('D').agg({
    'Cloud_Cover': 'mean',   
})

# %%
df_visibility = pd.read_csv("../data/freiburg raw data/freiburg visibility data/produkt_vk_termin_20230805_20250204_01443.txt", delimiter=";", usecols=["MESS_DATUM","VK_TER"])

df_visibility = df_visibility.rename(columns={
    "MESS_DATUM": "Measurement_Date",
    "VK_TER": "Visibility"
})
# Convert 'Measurement_Date' to datetime
df_visibility['Measurement_Date'] = pd.to_datetime(df_visibility['Measurement_Date'], format='%Y%m%d%H')

# Set the datetime column as the index
df_visibility.set_index('Measurement_Date', inplace=True)

# Resample to daily, aggregating with mean for visibility
df_visibility = df_visibility.resample('D').agg({
    'Visibility': 'mean'  # Average visibility for the day
})

# %%
df_precipitation = pd.read_csv(
    "../data/freiburg raw data/freiburg precipitation data/produkt_nieder_tag_20230805_20250204_01443.txt", delimiter=";", usecols=["MESS_DATUM","RS", "SH_TAG"])

df_precipitation = df_precipitation.rename(columns={
    "MESS_DATUM": "Measurement_Date",
    "RS": "Daily_Precipitation_Height",
    "SH_TAG": "Snow_Height_Daily_Value"
})

df_precipitation['Measurement_Date'] = pd.to_datetime(df_precipitation['Measurement_Date'], format='%Y%m%d')

df_precipitation.set_index('Measurement_Date', inplace=True)

df_precipitation_daily = df_precipitation

# %%
df_solar = pd.read_csv(
    "../data/freiburg raw data/freiburg solar data/Freiburg_Dach_solar_irradiance_2023-08-05_2025-02-04.csv", delimiter=",", usecols=["Beginn-Lokalzeit","Globalstrahlung (W/m²)"])

df_solar = df_solar.rename(columns={
    "Beginn-Lokalzeit": "Measurement_Date",
    "Globalstrahlung (W/m²)": "Global_Radiation"
})

df_solar['Measurement_Date'] = pd.to_datetime(df_solar['Measurement_Date'], format='%Y-%m-%d %H:%M:%S')  # Adjust the format if needed

df_solar.set_index('Measurement_Date', inplace=True)

df_solar_daily = df_solar.resample('D').sum()

# %%
df_wind = pd.read_csv(
    "../data/freiburg raw data/freiburg wind data/produkt_fk_termin_20230805_20250204_01443.txt", delimiter=";", usecols=["MESS_DATUM","DK_TER", "FK_TER"])

df_wind = df_wind.rename(columns={
    "MESS_DATUM": "Measurement_Date",
    "DK_TER": "Wind_Direction",
    "FK_TER": "Wind_Strength"
})

df_wind['Measurement_Date'] = pd.to_datetime(df_wind['Measurement_Date'], format='%Y%m%d%H')

df_wind.set_index('Measurement_Date', inplace=True)

df_wind_daily = df_wind.resample('D').agg({
    'Wind_Direction': 'mean',   
    'Wind_Strength': 'mean'  
})

# %%
df_air_pressure = pd.read_csv(
    "../data/freiburg raw data/freiburg air pressure data/produkt_pp_termin_20230805_20250204_01443.txt", delimiter=";", usecols=["MESS_DATUM", "PP_TER"])

df_air_pressure = df_air_pressure.rename(columns={
    "MESS_DATUM": "Measurement_Date",
    "PP_TER": "Air_Pressure_at_Station_Height"
})
df_air_pressure['Measurement_Date'] = pd.to_datetime(df_air_pressure['Measurement_Date'], format='%Y%m%d%H')

df_air_pressure.set_index('Measurement_Date', inplace=True)

df_air_pressure_daily = df_air_pressure.resample('D').agg({
    'Air_Pressure_at_Station_Height': 'mean',
})

# %%
df_vapour_pressure_and_rel_humidity = pd.read_csv(
    "../data/freiburg raw data/freiburg vapour pressure and relative humidity/produkt_tf_termin_20230805_20250204_01443.txt", delimiter=";", usecols=["MESS_DATUM", "RF_TER", "TF_TER", "VP_TER"])

df_vapour_pressure_and_rel_humidity = df_vapour_pressure_and_rel_humidity.rename(columns={
    "MESS_DATUM": "Measurement_Date",
    "RF_TER": "Relative_Humidity",
    "TF_TER": "Dew_Point_Temperature",
    "VP_TER": "Vapor_Pressure"
})

df_vapour_pressure_and_rel_humidity['Measurement_Date'] = pd.to_datetime(
    df_vapour_pressure_and_rel_humidity["Measurement_Date"], format="%Y%m%d%H")

df_vapour_pressure_and_rel_humidity.set_index('Measurement_Date', inplace=True)

df_vapour_pressure_and_rel_humidity = df_vapour_pressure_and_rel_humidity.resample('D').agg({
    "Vapor_Pressure": "mean",
    "Dew_Point_Temperature": 'mean'}
)

# %%
dataframes = [df_air_temperature_daily, df_visibility_daily, df_air_pressure_daily, df_cloudiness_daily, df_precipitation_daily, df_solar_daily, df_vapour_pressure_and_rel_humidity_daily, df_wind_daily]

# Concatenate all DataFrames along columns (axis=1), aligning by the index
df_combined = pd.concat(dataframes, axis=1)

# Display the concatenated DataFrame
df_combined
# Out:
# No NaN values in Air Temperature
# No NaN values in Visibility
# No NaN values in Air Pressure
# No NaN values in Cloudiness
# No NaN values in Precipitation
# No NaN values in Solar Radiation
# No NaN values in Vapor Pressure and Humidity
# No NaN values in Wind
#                   Air_Temperature  Relative_Humidity  Visibility  \
# Measurement_Date
# 2023-08-05              18.666667          65.000000    8.666667
# 2023-08-06              14.333333          81.000000    8.333333
# 2023-08-07              16.200000          67.333333    9.000000
# 2023-08-08              18.266667          59.333333    9.000000
# 2023-08-09              20.666667          58.666667    8.666667
# ...                           ...                ...         ...
# 2025-01-31               5.000000          79.750000    8.500000
# 2025-02-01               1.425000          80.250000    7.750000
# 2025-02-02               2.950000          75.250000    8.000000
# 2025-02-03               1.800000          83.250000    7.000000
# 2025-02-04               0.750000          82.500000    7.000000
#
#                   Air_Pressure_at_Station_Height  Cloud_Cover  \
# Measurement_Date
# 2023-08-05                            986.300000     3.000000
# 2023-08-06                            985.800000     7.666667
# 2023-08-07                            992.166667     7.666667
# 2023-08-08                            990.300000     7.666667
# 2023-08-09                            990.433333     5.333333
# ...                                          ...          ...
# 2025-01-31                            998.375000     7.750000
# 2025-02-01                            999.325000     4.000000
# 2025-02-02                            995.650000     8.000000
# 2025-02-03                            998.800000     8.000000
# 2025-02-04                           1001.375000     4.750000
#
#                   Daily_Precipitation_Height  Snow_Height_Daily_Value  \
# Measurement_Date
# 2023-08-05                               3.1                        0
# 2023-08-06                              10.1                        0
# 2023-08-07                               0.6                        0
# 2023-08-08                               0.2                        0
# 2023-08-09                               0.1                        0
# ...                                      ...                      ...
# 2025-01-31                               0.0                        0
# 2025-02-01                               0.0                        0
# 2025-02-02                               0.0                        0
# 2025-02-03                               0.0                        0
# 2025-02-04                               0.0                        0
#
#                   Global_Radiation  Vapor_Pressure  Dew_Point_Temperature  \
# Measurement_Date
# 2023-08-05               278.56710       13.500000              14.300000
# 2023-08-06                71.56500       13.200000              12.433333
# 2023-08-07               159.84050       12.233333              12.633333
# 2023-08-08               193.56080       12.000000              13.233333
# 2023-08-09                87.33178       14.366667              15.600000
# ...                            ...             ...                    ...
# 2025-01-31                43.60800        7.000000               3.575000
# 2025-02-01                68.79803        5.400000               0.150000
# 2025-02-02                57.14430        5.700000               1.350000
# 2025-02-03                19.00932        5.825000               0.800000
# 2025-02-04                80.89738        5.325000              -0.275000
#
#                   Wind_Direction  Wind_Strength
# Measurement_Date
# 2023-08-05             25.333333       2.000000
# 2023-08-06             22.666667       3.000000
# 2023-08-07             21.333333       2.333333
# 2023-08-08             26.666667       1.666667
# 2023-08-09             24.000000       2.333333
# ...                          ...            ...
# 2025-01-31             29.000000       1.750000
# 2025-02-01             19.000000       1.750000
# 2025-02-02             23.000000       1.750000
# 2025-02-03             24.000000       1.500000
# 2025-02-04             21.000000       1.500000
#
# [550 rows x 12 columns]
